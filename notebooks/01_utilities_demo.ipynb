# %% [markdown]
# # Utilities Demo
#
# This notebook shows how to import helper functions from the `utilities` folder and call them in a data-science workflow.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent.resolve()))

# %%
from utilities.water_helpers import (
    classify_quality,
    estimate_demand,
    summarize_flow,
)

print("Imports worked successfully.")
# Out:
# Imports worked successfully.

# %%
# Example 1: summarize a list of flow values
flow_summary = summarize_flow([10, 12, 14, 18])
print("Flow summary:", flow_summary)
# Out:
# Flow summary: {'count': 4, 'mean': 13.5, 'min': 10, 'max': 18}

# %%
# Example 2: classify a water-quality result
label = classify_quality(7.2)
print("Quality label:", label)
# Out:
# Quality label: balanced

# %%
# Example 3: estimate water demand
demand = estimate_demand(5000, 120)
print("Estimated demand (L/day):", demand)
# Out:
# Estimated demand (L/day): 600000
